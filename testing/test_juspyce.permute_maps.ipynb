# %% [markdown]
# # JuSpyce API test: null maps generation & permutation test

# %%
import sys
import os
from glob import glob
import pathlib
import numpy as np
import pandas as pd
from IPython.display import display
import seaborn as sns
import matplotlib.pyplot as plt

# current path
wd = pathlib.Path().resolve().parent
print(wd)

# import juspyce
sys.path.append(os.path.dirname(os.path.join(wd, "juspyce")))
from juspyce.api import JuSpyce
from juspyce.stats import *
from juspyce.utils import *
# Out:
# /Users/llotter/projects/juspyce

# %% [markdown]
# ## Load JuSpyce data from test_juspyce.fit.ipynb

# %%
juspyce_vol = JuSpyce.from_pickle(os.path.join(wd, "testing", "test_juspyce_vol_predicted.pkl.gz"))
# Out:
# INFO:juspyce.api:Loaded complete object from /Users/llotter/projects/juspyce/testing/test_juspyce_vol_predicted.pkl.gz.

# %% [markdown]
# ## Permutation based on null maps
#
# Uses the method from brainsmash based on variograms to correct for spatial autocorrelation. Distance maps are based on geodesic distances for surface parcellations and euclidean distances for volumetric parcellations.
#
# One has to choose a method for which empirical p-values will be calculated. If the `JuSpyce.permute_maps()` method is then applied again for computation of another metric, the already existing null maps will be used (this behavior can be turned off).

# %%
# everything below that is set to None will be set to customs or taken from the .fit() method
_ = juspyce_vol.permute_maps(
    method="dominance", # which method
    permute="X", # null maps for which dataset? Can be 'X' or 'Y'
    null_method="variogram", # "variogram" -> brainsmash, "random" -> np.random
    null_maps=None, # directly provide null maps. Must be dict with keys corresponding to the maps
                    # for which null data is generated (e.g., "mGluR5" or so)
    use_null_maps=True, # re-use null maps if already computed for another prediction method
    dist_mat=None, # custom distance matrix -> must be ndarray with shape (n_parcels, n_parcels) 
                   # or tuple of those ndarrays if parcellation is tuple of giftis
    n_perm=1000, # number if permutations (= number of null maps)
    parcellation=None, parc_space=None, parc_hemi=None, # parcellation data, usually set at .fit()
    centroids=False, # compute distance matrices between parcel centroids? -> faster
    r_to_z=None, adjust_r2=None, mlr_individual=None, # settings for prediction (see above)
    p_tail=None, # which-sided p-value? Must be dict with e.g. 
                 # {"spearman":"two"} or 
                 # {"dominance_total":"upper", "dominance_relative":"upper", 
                 #  "dominance_full_r2":"upper", "dominance_individual":"upper"}, etc.
    n_proc=None, # number of processes
    n_proc_predict=1, # number of processes for prediction method -> multiplies itself with n_proc!
    seed=None, # seed for reproducability
    store=True)
# Out:
# Null predictions (dominance, 8 proc):   0%|          | 0/1000 [00:00<?, ?it/s]
# INFO:juspyce.api:Calculating exact p-values (tails = {'dominance_total': 'upper', 'dominance_individual': 'upper', 'dominance_relative': 'upper', 'dominance_full_r2': 'upper'}).

# %% [markdown]
# ### Print result
#
# All results are stored in a dict as `JuSpyce.p_predictions["prediction_name"]` which corresponds to `JuSpyce.predictions["prediction_name"]`

# %%
for dom in ["dominance_full_r2", "dominance_relative", "dominance_total", "dominance_individual"]:
    print(dom)
    display(juspyce_vol.p_predictions[dom])
# Out:
# dominance_full_r2
#                dominance_full_r2
# control                    0.003
# touch                      0.102
# interoception              0.048
# learning                   0.001
# attention                  0.732
# language                   0.495
# interaction                0.097
# inhibition                 0.068
# somatosensory              0.104
# decision                   0.001
# auditory                   0.077
# taste                      0.001
# metabolism                 0.001
# memory                     0.202
# empathy                    0.106
# vision                     0.065
# autonomic                  0.015
# visual                     0.017
# fear                       0.004
# perception                 0.684
# cognition                  0.423
# reward                     0.001
# mirror                     0.145
# orientation                0.279
# movement                   0.079
# default_mode               0.055
# dopamine                   0.001
# pain                       0.001
# dominance_relative
#                5HT2a-cimbi36-29-beliveau2017  NMDA-ge179-29-galovic2021  \
# control                                0.166                      0.774
# touch                                  0.223                      0.602
# interoception                          0.790                      0.206
# learning                               0.423                      0.529
# attention                              0.842                      0.490
# language                               0.035                      0.830
# interaction                            0.586                      0.660
# inhibition                             0.150                      0.668
# somatosensory                          0.261                      0.563
# decision                               0.694                      0.787
# auditory                               0.519                      0.300
# taste                                  0.567                      0.099
# metabolism                             0.429                      0.151
# memory                                 0.596                      0.931
# empathy                                0.636                      0.474
# vision                                 0.799                      0.693
# autonomic                              0.681                      0.185
# visual                                 0.829                      0.773
# fear                                   0.335                      0.645
# perception                             0.643                      0.733
# cognition                              0.387                      0.608
# reward                                 0.585                      0.624
# mirror                                 0.320                      0.368
# orientation                            0.902                      0.658
# movement                               0.166                      0.539
# default_mode                           0.322                      0.222
# dopamine                               0.542                      0.608
# pain                                   0.344                      0.426
#
#                mGluR5-abp688-73-smart2019  MU-carfentanil-204-kantonen2020  \
# control                             0.426                            0.462
# touch                               0.109                            0.473
# interoception                       0.095                            0.232
# learning                            0.189                            0.618
# attention                           0.643                            0.006
# language                            0.292                            0.654
# interaction                         0.351                            0.004
# inhibition                          0.377                            0.512
# somatosensory                       0.075                            0.478
# decision                            0.663                            0.290
# auditory                            0.016                            0.485
# taste                               0.793                            0.097
# metabolism                          0.279                            0.639
# memory                              0.170                            0.413
# empathy                             0.007                            0.319
# vision                              0.161                            0.012
# autonomic                           0.168                            0.124
# visual                              0.110                            0.023
# fear                                0.165                            0.080
# perception                          0.626                            0.004
# cognition                           0.551                            0.120
# reward                              0.648                            0.206
# mirror                              0.421                            0.095
# orientation                         0.147                            0.011
# movement                            0.484                            0.153
# default_mode                        0.304                            0.358
# dopamine                            0.659                            0.207
# pain                                0.205                            0.356
#
#                GABAa-flumazenil-6-dukart2018  5HT1b-p943-65-gallezot2010  \
# control                                0.230                       0.542
# touch                                  0.523                       0.673
# interoception                          0.710                       0.727
# learning                               0.494                       0.879
# attention                              0.708                       0.829
# language                               0.452                       0.405
# interaction                            0.737                       0.893
# inhibition                             0.301                       0.403
# somatosensory                          0.552                       0.726
# decision                               0.476                       0.114
# auditory                               0.460                       0.925
# taste                                  0.544                       0.931
# metabolism                             0.387                       0.452
# memory                                 0.628                       0.040
# empathy                                0.589                       0.920
# vision                                 0.572                       0.803
# autonomic                              0.756                       0.768
# visual                                 0.525                       0.951
# fear                                   0.494                       0.561
# perception                             0.659                       0.398
# cognition                              0.520                       0.727
# reward                                 0.556                       0.254
# mirror                                 0.532                       0.925
# orientation                            0.635                       0.771
# movement                               0.449                       0.778
# default_mode                           0.353                       0.637
# dopamine                               0.466                       0.239
# pain                                   0.348                       0.587
#
#                D2-raclopride-156-malen2022
# control                              0.374
# touch                                0.324
# interoception                        0.449
# learning                             0.094
# attention                            0.482
# language                             0.812
# interaction                          0.790
# inhibition                           0.430
# somatosensory                        0.333
# decision                             0.113
# auditory                             0.568
# taste                                0.486
# metabolism                           0.541
# memory                               0.662
# empathy                              0.590
# vision                               0.601
# autonomic                            0.512
# visual                               0.588
# fear                                 0.750
# perception                           0.540
# cognition                            0.150
# reward                               0.104
# mirror                               0.422
# orientation                          0.601
# movement                             0.430
# default_mode                         0.619
# dopamine                             0.137
# pain                                 0.375
# dominance_total
#                5HT2a-cimbi36-29-beliveau2017  NMDA-ge179-29-galovic2021  \
# control                                0.030                      0.603
# touch                                  0.121                      0.456
# interoception                          0.693                      0.078
# learning                               0.045                      0.095
# attention                              0.852                      0.516
# language                               0.061                      0.810
# interaction                            0.448                      0.535
# inhibition                             0.067                      0.532
# somatosensory                          0.140                      0.419
# decision                               0.224                      0.344
# auditory                               0.328                      0.154
# taste                                  0.277                      0.002
# metabolism                             0.064                      0.001
# memory                                 0.472                      0.863
# empathy                                0.509                      0.341
# vision                                 0.729                      0.606
# autonomic                              0.565                      0.050
# visual                                 0.739                      0.671
# fear                                   0.110                      0.409
# perception                             0.652                      0.740
# cognition                              0.344                      0.578
# reward                                 0.104                      0.150
# mirror                                 0.227                      0.248
# orientation                            0.875                      0.613
# movement                               0.080                      0.402
# default_mode                           0.160                      0.079
# dopamine                               0.137                      0.218
# pain                                   0.084                      0.131
#
#                mGluR5-abp688-73-smart2019  MU-carfentanil-204-kantonen2020  \
# control                             0.234                            0.262
# touch                               0.025                            0.320
# interoception                       0.028                            0.117
# learning                            0.003                            0.211
# attention                           0.674                            0.009
# language                            0.287                            0.651
# interaction                         0.230                            0.001
# inhibition                          0.231                            0.355
# somatosensory                       0.018                            0.334
# decision                            0.231                            0.009
# auditory                            0.001                            0.299
# taste                               0.576                            0.003
# metabolism                          0.010                            0.222
# memory                              0.082                            0.306
# empathy                             0.001                            0.189
# vision                              0.106                            0.001
# autonomic                           0.064                            0.040
# visual                              0.034                            0.001
# fear                                0.041                            0.011
# perception                          0.637                            0.012
# cognition                           0.506                            0.105
# reward                              0.232                            0.003
# mirror                              0.326                            0.047
# orientation                         0.117                            0.002
# movement                            0.364                            0.068
# default_mode                        0.159                            0.225
# dopamine                            0.283                            0.004
# pain                                0.029                            0.095
#
#                GABAa-flumazenil-6-dukart2018  5HT1b-p943-65-gallezot2010  \
# control                                0.070                       0.369
# touch                                  0.390                       0.564
# interoception                          0.600                       0.618
# learning                               0.064                       0.541
# attention                              0.726                       0.850
# language                               0.426                       0.391
# interaction                            0.632                       0.831
# inhibition                             0.166                       0.270
# somatosensory                          0.423                       0.615
# decision                               0.049                       0.001
# auditory                               0.267                       0.842
# taste                                  0.249                       0.758
# metabolism                             0.020                       0.058
# memory                                 0.497                       0.021
# empathy                                0.462                       0.851
# vision                                 0.477                       0.742
# autonomic                              0.625                       0.658
# visual                                 0.387                       0.905
# fear                                   0.268                       0.349
# perception                             0.676                       0.428
# cognition                              0.483                       0.708
# reward                                 0.124                       0.007
# mirror                                 0.423                       0.877
# orientation                            0.593                       0.739
# movement                               0.319                       0.685
# default_mode                           0.190                       0.523
# dopamine                               0.098                       0.011
# pain                                   0.084                       0.314
#
#                D2-raclopride-156-malen2022
# control                              0.152
# touch                                0.173
# interoception                        0.306
# learning                             0.001
# attention                            0.517
# language                             0.805
# interaction                          0.704
# inhibition                           0.269
# somatosensory                        0.178
# decision                             0.001
# auditory                             0.401
# taste                                0.186
# metabolism                           0.107
# memory                               0.575
# empathy                              0.433
# vision                               0.512
# autonomic                            0.349
# visual                               0.472
# fear                                 0.584
# perception                           0.568
# cognition                            0.134
# reward                               0.001
# mirror                               0.293
# orientation                          0.555
# movement                             0.295
# default_mode                         0.453
# dopamine                             0.001
# pain                                 0.100
# dominance_individual
#                5HT2a-cimbi36-29-beliveau2017  NMDA-ge179-29-galovic2021  \
# control                                0.036                      0.727
# touch                                  0.349                      0.476
# interoception                          0.660                      0.035
# learning                               0.001                      0.001
# attention                              0.685                      0.395
# language                               0.143                      0.733
# interaction                            0.551                      0.981
# inhibition                             0.104                      0.620
# somatosensory                          0.420                      0.425
# decision                               0.018                      0.219
# auditory                               0.221                      0.398
# taste                                  0.030                      0.001
# metabolism                             0.001                      0.001
# memory                                 0.501                      0.931
# empathy                                0.625                      0.310
# vision                                 0.650                      0.495
# autonomic                              0.495                      0.017
# visual                                 0.684                      0.566
# fear                                   0.067                      0.228
# perception                             0.542                      0.625
# cognition                              0.277                      0.633
# reward                                 0.001                      0.001
# mirror                                 0.543                      0.227
# orientation                            0.884                      0.561
# movement                               0.201                      0.414
# default_mode                           0.095                      0.487
# dopamine                               0.001                      0.009
# pain                                   0.019                      0.066
#
#                mGluR5-abp688-73-smart2019  MU-carfentanil-204-kantonen2020  \
# control                             0.167                            0.594
# touch                               0.416                            0.510
# interoception                       0.040                            0.020
# learning                            0.001                            0.028
# attention                           0.802                            0.014
# language                            0.269                            0.810
# interaction                         0.147                            0.006
# inhibition                          0.615                            0.740
# somatosensory                       0.286                            0.498
# decision                            0.344                            0.001
# auditory                            0.001                            0.882
# taste                               0.651                            0.001
# metabolism                          0.001                            0.060
# memory                              0.062                            0.198
# empathy                             0.010                            0.081
# vision                              0.251                            0.001
# autonomic                           0.111                            0.008
# visual                              0.172                            0.001
# fear                                0.095                            0.034
# perception                          0.747                            0.024
# cognition                           0.819                            0.072
# reward                              0.446                            0.001
# mirror                              0.705                            0.072
# orientation                         0.236                            0.005
# movement                            0.342                            0.141
# default_mode                        0.075                            0.336
# dopamine                            0.375                            0.001
# pain                                0.509                            0.012
#
#                GABAa-flumazenil-6-dukart2018  5HT1b-p943-65-gallezot2010  \
# control                                0.055                       0.817
# touch                                  0.690                       0.460
# interoception                          0.935                       0.641
# learning                               0.001                       0.741
# attention                              0.733                       0.816
# language                               0.681                       0.348
# interaction                            0.918                       0.685
# inhibition                             0.183                       0.574
# somatosensory                          0.803                       0.528
# decision                               0.001                       0.001
# auditory                               0.217                       0.812
# taste                                  0.078                       0.800
# metabolism                             0.001                       0.008
# memory                                 0.860                       0.013
# empathy                                0.941                       0.999
# vision                                 0.609                       0.863
# autonomic                              0.876                       0.757
# visual                                 0.604                       0.977
# fear                                   0.319                       0.256
# perception                             0.567                       0.545
# cognition                              0.533                       0.660
# reward                                 0.001                       0.013
# mirror                                 0.688                       0.884
# orientation                            0.787                       0.850
# movement                               0.352                       0.979
# default_mode                           0.033                       0.638
# dopamine                               0.001                       0.038
# pain                                   0.073                       0.156
#
#                D2-raclopride-156-malen2022
# control                              0.943
# touch                                0.473
# interoception                        0.139
# learning                             0.001
# attention                            0.370
# language                             0.809
# interaction                          0.750
# inhibition                           0.997
# somatosensory                        0.440
# decision                             0.001
# auditory                             0.530
# taste                                0.008
# metabolism                           0.138
# memory                               0.452
# empathy                              0.708
# vision                               0.487
# autonomic                            0.151
# visual                               0.584
# fear                                 0.485
# perception                           0.347
# cognition                            0.062
# reward                               0.001
# mirror                               0.443
# orientation                          0.664
# movement                             0.672
# default_mode                         0.367
# dopamine                             0.001
# pain                                 0.540

# %% [markdown]
# ## Correct p-values
#
# p values can be corrected across dataframes or rows/columns of dataframes using `JuSpyce.correct_p()`. The method will, if not provided differently, loop over all p-value dataframes and apply multiple comparison correction methods from `statsmodels.stats.multitest.multipletests`.
#
# Results will be stored in the `JuSpyce.p_predictions` dict as `JuSpyce.p_predictions`["prediction_name-correction_method"], e.g., if method is `spearman` and correction is `fdr_bh:` juspyce_vol.p_predictions["spearman-fdr_bh"]`

# %%
juspyce_vol.correct_p(
    analysis="predictions", # one of "predictions" or "group_comparisons" -> here: predictions
    method="all", # if all, iterate over all dataframes (but calculate values for each individual dataframe)
    mc_alpha=0.05, # alpha treshold, should have no effect
    mc_method="fdr_bh", # correction method passed to statsmodels
    mc_dimension="array") # 'array', 'row' or 'column'
display(juspyce_vol.p_predictions["dominance_total-fdr_bh"])
# Out:
#                5HT2a-cimbi36-29-beliveau2017  NMDA-ge179-29-galovic2021  \
# control                             0.189677                   0.733185
# touch                               0.370562                   0.662044
# interoception                       0.771750                   0.316615
# learning                            0.252000                   0.344815
# attention                           0.869750                   0.694055
# language                            0.291721                   0.848984
# interaction                         0.660211                   0.703758
# inhibition                          0.296178                   0.703758
# somatosensory                       0.397681                   0.640366
# decision                            0.504000                   0.584650
# auditory                            0.579171                   0.419222
# taste                               0.548404                   0.030154
# metabolism                          0.291721                   0.017818
# memory                              0.670377                   0.876414
# empathy                             0.694055                   0.584650
# vision                              0.790391                   0.733185
# autonomic                           0.721580                   0.257895
# visual                              0.790391                   0.761471
# fear                                0.353443                   0.636222
# perception                          0.751718                   0.790391
# cognition                           0.584650                   0.721580
# reward                              0.349533                   0.419222
# mirror                              0.504000                   0.524774
# orientation                         0.881497                   0.734109
# movement                            0.316615                   0.630336
# default_mode                        0.423784                   0.316615
# dopamine                            0.394882                   0.504000
# pain                                0.316615                   0.389030
#
#                mGluR5-abp688-73-smart2019  MU-carfentanil-204-kantonen2020  \
# control                          0.504000                         0.540000
# touch                            0.175000                         0.575413
# interoception                    0.189241                         0.364000
# learning                         0.036750                         0.504000
# attention                        0.761471                         0.088200
# language                         0.556951                         0.751718
# interaction                      0.504000                         0.017818
# inhibition                       0.504000                         0.589661
# somatosensory                    0.141120                         0.584500
# decision                         0.504000                         0.088200
# auditory                         0.017818                         0.563500
# taste                            0.721580                         0.036750
# metabolism                       0.093333                         0.504000
# memory                           0.316615                         0.565811
# empathy                          0.017818                         0.465500
# vision                           0.349533                         0.017818
# autonomic                        0.291721                         0.236353
# visual                           0.208250                         0.017818
# fear                             0.236353                         0.093739
# perception                       0.743167                         0.098000
# cognition                        0.694055                         0.349533
# reward                           0.504000                         0.036750
# mirror                           0.579171                         0.255889
# orientation                      0.364000                         0.030154
# movement                         0.599529                         0.296178
# default_mode                     0.423784                         0.504000
# dopamine                         0.554680                         0.046118
# pain                             0.189467                         0.344815
#
#                GABAa-flumazenil-6-dukart2018  5HT1b-p943-65-gallezot2010  \
# control                             0.298261                    0.602700
# touch                               0.623057                    0.721580
# interoception                       0.733185                    0.734109
# learning                            0.291721                    0.706907
# attention                           0.790391                    0.869750
# language                            0.640366                    0.623057
# interaction                         0.741749                    0.866362
# inhibition                          0.433813                    0.540000
# somatosensory                       0.640366                    0.734109
# decision                            0.257895                    0.017818
# auditory                            0.540000                    0.869750
# taste                               0.524774                    0.803070
# metabolism                          0.150769                    0.291487
# memory                              0.690865                    0.152444
# empathy                             0.665824                    0.869750
# vision                              0.672604                    0.790391
# autonomic                           0.737952                    0.754199
# visual                              0.623057                    0.905000
# fear                                0.540000                    0.584650
# perception                          0.761471                    0.640366
# cognition                           0.676200                    0.779595
# reward                              0.373908                    0.076222
# mirror                              0.640366                    0.881497
# orientation                         0.730994                    0.790391
# movement                            0.575413                    0.767200
# default_mode                        0.465500                    0.697333
# dopamine                            0.349236                    0.093739
# pain                                0.316615                    0.575178
#
#                D2-raclopride-156-malen2022
# control                           0.419222
# touch                             0.446158
# interoception                     0.565811
# learning                          0.017818
# attention                         0.694055
# language                          0.848280
# interaction                       0.779571
# inhibition                        0.540000
# somatosensory                     0.453091
# decision                          0.017818
# auditory                          0.630336
# taste                             0.465500
# metabolism                        0.349533
# memory                            0.721580
# empathy                           0.642939
# vision                            0.694055
# autonomic                         0.584650
# visual                            0.670377
# fear                              0.724456
# perception                        0.721580
# cognition                         0.392000
# reward                            0.017818
# mirror                            0.561359
# orientation                       0.720397
# movement                          0.561359
# default_mode                      0.662044
# dopamine                          0.017818
# pain                              0.349533
